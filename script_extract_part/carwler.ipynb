# %%
import requests
import pandas as pd
import math, json
from bs4 import BeautifulSoup
import re
from IPython.display import clear_output
import numpy as np

from concurrent.futures import ThreadPoolExecutor, wait

# %%
#Removes request warnings from console

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
def getNamesOfMovies(genre):
    headers = {
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Referer': 'https://imsdb.com/',
        'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    }
    response = requests.get(f"http://imsdb.com/genre/{genre}", headers=headers, verify=False)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    movie_names=[]
    for row in soup.find_all('p'):
        movie_names.append(row.find('a').get('title'))
    return movie_names

# %%
def getMovieInfos(movie_name):
    from urllib import parse
    headers = {
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Referer': 'https://imsdb.com/',
        'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    }
    response = requests.get(f"http://imsdb.com/Movie%20Scripts/{parse.quote(movie_name)}.html", headers=headers, verify=False)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    movie_detail = soup.find(class_='script-details')
    all_a = movie_detail.find_all('a')
    genres = []
    authors = []
    for a in all_a:
        text = a.text
        if a['href'].startswith('/writer'):
            authors.append(text)
        if a['href'].startswith('/genre'):
            genres.append(text)
    
    movie_info = {
        'imgSrc': movie_detail.find('img')['src'],
        'title': movie_name.replace(' Script', ''),
        'genres': genres,
        'authors': authors,
    }
    
    return movie_info

# %%
genres = ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Short', 'Thriller', 'War', 'Western']

def collect_movie_names_for_all_genres():
    movie_name_list = set()
    for genre in genres:
        movie_names = getNamesOfMovies(genre)
        print(genre, len(movie_names))
        if len(movie_names) > 0:
            movie_name_list = movie_name_list | set(movie_names)

    return movie_name_list

# %%
movie_name_set = list(collect_movie_names_for_all_genres())
# Out:
# Action 336
# Adventure 203
# Animation 45
# Comedy 394
# Crime 231
# Drama 652
# Family 53
# Fantasy 130
# Film-Noir 4
# Horror 158
# Musical 27
# Mystery 123
# Romance 211
# Sci-Fi 180
# Short 3
# Thriller 406
# War 32
# Western 17

# %%
getMovieInfos(movie_name_set[0])
# Out:
# {'imgSrc': '/images/no-poster.gif',
#  'title': 'Hellraiser',
#  'genres': ['Horror'],
#  'authors': ['Clive Barker']}

# %%
def get_all_movie_infos():
    movie_info_list = []
    print(f"total {len(movie_name_set)}")
    for i, movie in enumerate(movie_name_set):
        print(f'{i}/{len(movie_name_set)}---- start')
        try:
            movie_info = getMovieInfos(movie)
            movie_info_list.append(movie_info)
            print(f'{movie} success')
        except BaseException as e:
            print(f"failed {movie} due to {str(e)}")
    return movie_info_list

# %%
movie_infos = get_all_movie_infos()
# Out:
# total 1209
# 0/1209---- start
# Hellraiser Script success
# 1/1209---- start
# Artist, The Script success
# 2/1209---- start
# Pacifier, The Script success
# 3/1209---- start
# Terminator 2: Judgement Day Script success
# 4/1209---- start
# Game, The Script success
# 5/1209---- start
# American Pie Script success
# 6/1209---- start
# Superbad Script success
# 7/1209---- start
# Ghost Ship Script success
# 8/1209---- start
# Sweeney Todd: The Demon Barber of Fleet Street Script success
# 9/1209---- start
# Fruitvale Station Script success
# 10/1209---- start
# Beasts of the Southern Wild Script success
# 11/1209---- start
# Godfather Part II Script success
# 12/1209---- start
# Shampoo Script success
# 13/1209---- start
# Zero Dark Thirty Script success
# 14/1209---- start
# Unknown Script success
# 15/1209---- start
# Drive Angry Script success
# 16/1209---- start
# My Mother Dreams the Satan's Disciples in New York Script success
# 17/1209---- start
# G.I. Jane Script success
# 18/1209---- start
# Lord of the Rings: Fellowship of the Ring, The Script success
# 19/1209---- start
# Date Night Script success
# 20/1209---- start
# Curious Case of Benjamin Button, The Script success
# 21/1209---- start
# Wanted Script success
# 22/1209---- start
# JFK Script success
# 23/1209---- start
# Carrie Script success
# 24/1209---- start
# Sister Act Script success
# 25/1209---- start
# Amelia Script success
# 26/1209---- start
# Boxtrolls, The Script success
# 27/1209---- start
# Dark Knight Rises, The Script success
# 28/1209---- start
# Back to the Future Script success
# 29/1209---- start
# Training Day Script success
# 30/1209---- start
# Edward Scissorhands Script success
# 31/1209---- start
# Stepmom Script success
# 32/1209---- start
# Back-up Plan, The Script success
# 33/1209---- start
# Kids Script success
# 34/1209---- start
# Ides of March, The Script success
# 35/1209---- start
# Croods, The Script success
# 36/1209---- start
# Kill Your Darlings Script success
# 37/1209---- start
# Hotel Rwanda Script success
# 38/1209---- start
# Even Cowgirls Get the Blues Script success
# 39/1209---- start
# Next Three Days, The Script success
# 40/1209---- start
# Master and Commander Script success
# 41/1209---- start
# Fright Night (1985) Script success
# 42/1209---- start
# Dawn of the Dead Script success
# 43/1209---- start
# Gone in 60 Seconds Script success
# 44/1209---- start
# I Spit on Your Grave Script success
# 45/1209---- start
# Mission Impossible Script success
# 46/1209---- start
# Frozen River Script success
# 47/1209---- start
# Whistleblower, The Script success
# 48/1209---- start
# Gladiator Script success
# 49/1209---- start
# Thor Ragnarok Script success
# 50/1209---- start
# Kafka Script success
# 51/1209---- start
# Day the Earth Stood Still, The Script success
# 52/1209---- start
# Ninja Assassin Script success
# 53/1209---- start
# Clockwork Orange, A Script success
# 54/1209---- start
# Snow White and the Huntsman Script success
# 55/1209---- start
# Star Wars: Attack of the Clones Script success
# 56/1209---- start
# Haunting, The Script success
# 57/1209---- start
# Hostage Script success
# 58/1209---- start
# It Script success
# 59/1209---- start
# Apt Pupil Script success
# 60/1209---- start
# Diner Script success
# 61/1209---- start
# Toy Story Script success
# 62/1209---- start
# In the Loop Script success
# 63/1209---- start
# Drive Script success
# 64/1209---- start
# Zerophilia Script success
# 65/1209---- start
# All the President's Men Script success
# 66/1209---- start
# Rush Hour Script success
# 67/1209---- start
# Lord of War Script success
# 68/1209---- start
# Visitor, The Script success
# 69/1209---- start
# Kill Bill Volume 1 & 2 Script success
# 70/1209---- start
# Verdict, The Script success
# 71/1209---- start
# Ferris Bueller's Day Off Script success
# 72/1209---- start
# Field of Dreams Script success
# 73/1209---- start
# Planet of the Apes, The Script success
# 74/1209---- start
# Crying Game Script success
# 75/1209---- start
# Man On Fire Script success
# 76/1209---- start
# Twins Script success
# 77/1209---- start
# Kalifornia Script success
# 78/1209---- start
# Life of Pi Script success
# 79/1209---- start
# Strange Days Script success
# 80/1209---- start
# War Horse Script success
# 81/1209---- start
# An Education Script success
# 82/1209---- start
# Godfather Part III, The Script success
# 83/1209---- start
# Catch Me If You Can Script success
# 84/1209---- start
# Chronicles of Narnia: The Lion, the Witch and the Wardrobe Script success
# 85/1209---- start
# Bachelor Party Script success
# 86/1209---- start
# Lincoln Script success
# 87/1209---- start
# Silver Linings Playbook Script success
# 88/1209---- start
# A.I. Script success
# 89/1209---- start
# Bound Script success
# 90/1209---- start
# Pride and Prejudice Script success
# 91/1209---- start
# Virtuosity Script success
# 92/1209---- start
# Three Kings (Spoils of War) Script success
# 93/1209---- start
# Road, The Script success
# 94/1209---- start
# Purple Rain Script success
# 95/1209---- start
# Harry Potter and the Deathly Hallows Part 1 Script success
# 96/1209---- start
# Pleasantville Script success
# 97/1209---- start
# Synecdoche, New York Script success
# 98/1209---- start
# 8MM Script success
# 99/1209---- start
# Finding Nemo Script success
# 100/1209---- start
# Apollo 13 Script success
# 101/1209---- start
# Last of the Mohicans, The Script success
# 102/1209---- start
# Martian, The Script success
# 103/1209---- start
# Dallas Buyers Club Script success
# 104/1209---- start
# Insomnia Script success
# 105/1209---- start
# Black Snake Moan Script success
# 106/1209---- start
# Kate & Leopold Script success
# 107/1209---- start
# Cellular Script success
# 108/1209---- start
# Taking Lives Script success
# 109/1209---- start
# Eagle Eye Script success
# 110/1209---- start
# Friday the 13th Part VIII: Jason Takes Manhattan Script success
# 111/1209---- start
# Getaway, The Script success
# 112/1209---- start
# Big Script success
# 113/1209---- start
# Kingdom, The Script success
# 114/1209---- start
# Jimmy and Judy Script success
# 115/1209---- start
# Jeux Interdits Script success
# 116/1209---- start
# Pandorum Script success
# 117/1209---- start
# Robocop Script success
# 118/1209---- start
# Final Destination Script success
# 119/1209---- start
# Ninotchka Script success
# 120/1209---- start
# Water for Elephants Script success
# 121/1209---- start
# Reservoir Dogs Script success
# 122/1209---- start
# Prom Night Script success
# 123/1209---- start
# Days of Heaven Script success
# 124/1209---- start
# Sphere Script success
# 125/1209---- start
# Omega Man Script success
# 126/1209---- start
# Ocean's Twelve Script success
# 127/1209---- start
# Barry Lyndon Script success
# 128/1209---- start
# Boondock Saints, The Script success
# 129/1209---- start
# Last Samurai, The Script success
# 130/1209---- start
# Tall in the Saddle Script success
# 131/1209---- start
# Fargo Script success
# 132/1209---- start
# Sense and Sensibility Script success
# 133/1209---- start
# Eternal Sunshine of the Spotless Mind Script success
# 134/1209---- start
# Soldier Script success
# 135/1209---- start
# Officer and a Gentleman, An Script success
# 136/1209---- start
# Win Win Script success
# 137/1209---- start
# Perks of Being a Wallflower, The Script success
# 138/1209---- start
# Wall Street: Money Never Sleeps Script success
# 139/1209---- start
# 1492: Conquest of Paradise Script success
# 140/1209---- start
# Sunset Blvd. Script success
# 141/1209---- start
# Prophecy, The Script success
# 142/1209---- start
# Bull Durham Script success
# 143/1209---- start
# Departed, The Script success
# 144/1209---- start
# Love and Basketball Script success
# 145/1209---- start
# Body Heat Script success
# 146/1209---- start
# Fantastic Four Script success
# 147/1209---- start
# Freddy vs. Jason Script success
# 148/1209---- start
# Deep Rising Script success
# 149/1209---- start
# Yes Man Script success
# 150/1209---- start
# Siege, The Script success
# 151/1209---- start
# Evil Dead II: Dead by Dawn Script success
# 152/1209---- start
# Land of the Dead Script success
# 153/1209---- start
# Dragonslayer Script success
# 154/1209---- start
# American President, The Script success
# 155/1209---- start
# Milk Script success
# 156/1209---- start
# Wrestler, The Script success
# 157/1209---- start
# Speed Script success
# 158/1209---- start
# Snatch Script success
# 159/1209---- start
# After.Life Script success
# 160/1209---- start
# Assassins Script success
# 161/1209---- start
# Nightmare Before Christmas, The Script success
# 162/1209---- start
# Arbitrage Script success
# 163/1209---- start
# Grand Theft Parsons Script success
# 164/1209---- start
# Raising Arizona Script success
# 165/1209---- start
# Who Framed Roger Rabbit? Script success
# 166/1209---- start
# Iron Lady, The Script success
# 167/1209---- start
# Colombiana Script success
# 168/1209---- start
# Midnight in Paris Script success
# 169/1209---- start
# Shakespeare in Love Script success
# 170/1209---- start
# So I Married an Axe Murderer Script success
# 171/1209---- start
# Darkman Script success
# 172/1209---- start
# Time Machine, The Script success
# 173/1209---- start
# Bringing Out the Dead Script success
# 174/1209---- start
# Rocky Script success
# 175/1209---- start
# Traffic Script success
# 176/1209---- start
# Arthur Script success
# 177/1209---- start
# Malcolm X Script success
# 178/1209---- start
# Timber Falls Script success
# 179/1209---- start
# Feast Script success
# 180/1209---- start
# Anniversary Party, The Script success
# 181/1209---- start
# Remember Me Script success
# 182/1209---- start
# Fright Night Script success
# 183/1209---- start
# He's Just Not That Into You Script success
# 184/1209---- start
# Hall Pass Script success
# 185/1209---- start
# Pineapple Express Script success
# 186/1209---- start
# Speed Racer Script success
# 187/1209---- start
# Tropic Thunder Script success
# 188/1209---- start
# Ni vu ni connu Script success
# 189/1209---- start
# Flight Script success
# 190/1209---- start
# Titanic Script success
# 191/1209---- start
# Defiance Script success
# 192/1209---- start
# Bonnie and Clyde Script success
# 193/1209---- start
# Anna Karenina Script success
# 194/1209---- start
# Memento Script success
# 195/1209---- start
# Scream 2 Script success
# 196/1209---- start
# Burn After Reading Script success
# 197/1209---- start
# Made Script success
# 198/1209---- start
# Get Low Script success
# 199/1209---- start
# S. Darko Script success
# 200/1209---- start
# Twilight Script success
# 201/1209---- start
# Music of the Heart Script success
# 202/1209---- start
# Pariah Script success
# 203/1209---- start
# Patriot, The Script success
# 204/1209---- start
# Rise of the Guardians Script success
# 205/1209---- start
# I, Robot Script success
# 206/1209---- start
# Crazy, Stupid, Love Script success
# 207/1209---- start
# Blood and Wine Script success
# 208/1209---- start
# G.I. Joe: The Rise of Cobra Script success
# 209/1209---- start
# Good Will Hunting Script success
# 210/1209---- start
# Newsies Script success
# 211/1209---- start
# Monte Carlo Script success
# 212/1209---- start
# Lion King, The Script success
# 213/1209---- start
# Matrix Reloaded, The Script success
# 214/1209---- start
# Smashed Script success
# 215/1209---- start
# Max Payne Script success
# 216/1209---- start
# Shining, The Script success
# 217/1209---- start
# Dead Poets Society Script success
# 218/1209---- start
# Clueless Script success
# 219/1209---- start
# Saint, The Script success
# 220/1209---- start
# Hangover, The Script success
# 221/1209---- start
# eXistenZ Script success
# 222/1209---- start
# Badlands Script success
# 223/1209---- start
# Breakdown Script success
# 224/1209---- start
# Ghostbusters Script success
# 225/1209---- start
# Bad Lieutenant Script success
# 226/1209---- start
# Salton Sea, The Script success
# 227/1209---- start
# Star Wars: The Force Awakens Script success
# 228/1209---- start
# American, The Script success
# 229/1209---- start
# Law Abiding Citizen Script success
# 230/1209---- start
# A Quiet Place Script success
# 231/1209---- start
# Public Enemies Script success
# 232/1209---- start
# Hellraiser: Hellseeker Script success
# 233/1209---- start
# Leaving Las Vegas Script success
# 234/1209---- start
# English Patient, The Script success
# 235/1209---- start
# Elizabeth: The Golden Age Script success
# 236/1209---- start
# Real Genius Script success
# 237/1209---- start
# Signs Script success
# 238/1209---- start
# Halloween Script success
# 239/1209---- start
# Army of Darkness Script success
# 240/1209---- start
# Rise of the Planet of the Apes Script success
# 241/1209---- start
# Storytelling Script success
# 242/1209---- start
# Insider, The Script success
# 243/1209---- start
# Mr Blandings Builds His Dream House Script success
# 244/1209---- start
# Minority Report Script success
# 245/1209---- start
# Shadow of the Vampire Script success
# 246/1209---- start
# Mystery Men Script success
# 247/1209---- start
# Legion Script success
# 248/1209---- start
# Little Athens Script success
# 249/1209---- start
# Lost in Space Script success
# 250/1209---- start
# Dog Day Afternoon Script success
# 251/1209---- start
# Tombstone Script success
# 252/1209---- start
# Superfights Script success
# 253/1209---- start
# Babel Script success
# 254/1209---- start
# Kiss of the Spider Woman Script success
# 255/1209---- start
# Misery Script success
# 256/1209---- start
# Hancock Script success
# 257/1209---- start
# Color of Night Script success
# 258/1209---- start
# Lord of the Rings: Return of the King Script success
# 259/1209---- start
# Equilibrium Script success
# 260/1209---- start
# Slumdog Millionaire Script success
# 261/1209---- start
# Autumn in New York Script success
# 262/1209---- start
# Cell, The Script success
# 263/1209---- start
# Thing, The Script success
# 264/1209---- start
# This Boy's Life Script success
# 265/1209---- start
# American Gangster Script success
# 266/1209---- start
# Predator Script success
# 267/1209---- start
# Clerks Script success
# 268/1209---- start
# Aladdin Script success
# 269/1209---- start
# Angels & Demons Script success
# 270/1209---- start
# Pretty Woman (final script) Script success
# 271/1209---- start
# Bamboozled Script success
# 272/1209---- start
# Beavis and Butt-head Do America Script success
# 273/1209---- start
# Office Space Script success
# 274/1209---- start
# Code of Silence Script success
# 275/1209---- start
# Believer, The Script success
# 276/1209---- start
# Miami Vice Script success
# 277/1209---- start
# Deep Cover Script success
# 278/1209---- start
# Incredibles, The Script success
# 279/1209---- start
# Save the Last Dance Script success
# 280/1209---- start
# In the Bedroom Script success
# 281/1209---- start
# Happy Feet Script success
# 282/1209---- start
# Life of David Gale, The Script success
# 283/1209---- start
# Petulia Script success
# 284/1209---- start
# Sugar Script success
# 285/1209---- start
# John Q Script success
# 286/1209---- start
# Postman, The Script success
# 287/1209---- start
# American Werewolf in London Script success
# 288/1209---- start
# Magnolia Script success
# 289/1209---- start
# Blues Brothers, The Script success
# 290/1209---- start
# Grand Hotel Script success
# 291/1209---- start
# Hellraiser: Deader Script success
# 292/1209---- start
# Angel Eyes Script success
# 293/1209---- start
# Cliffhanger Script success
# 294/1209---- start
# Bottle Rocket Script success
# 295/1209---- start
# Men in Black Script success
# 296/1209---- start
# Battle of Algiers, The Script success
# 297/1209---- start
# Donnie Brasco Script success
# 298/1209---- start
# Thunderbirds Script success
# 299/1209---- start
# Six Degrees of Separation Script success
# 300/1209---- start
# Pirates of the Caribbean: Dead Man's Chest Script success
# 301/1209---- start
# Outbreak Script success
# 302/1209---- start
# Cecil B. Demented Script success
# 303/1209---- start
# Conan the Barbarian Script success
# 304/1209---- start
# As Good As It Gets Script success
# 305/1209---- start
# Labor of Love Script success
# 306/1209---- start
# Last Tango in Paris Script success
# 307/1209---- start
# Shawshank Redemption, The Script success
# 308/1209---- start
# Informant, The Script success
# 309/1209---- start
# Year One Script success
# 310/1209---- start
# She's Out of My League Script success
# 311/1209---- start
# Analyze That Script success
# 312/1209---- start
# Margaret Script success
# 313/1209---- start
# Rear Window Script success
# 314/1209---- start
# Mr. Holland's Opus Script success
# 315/1209---- start
# August: Osage County Script success
# 316/1209---- start
# Solaris Script success
# 317/1209---- start
# Psycho Script success
# 318/1209---- start
# Proposal, The Script success
# 319/1209---- start
# Saving Private Ryan Script success
# 320/1209---- start
# xXx Script success
# 321/1209---- start
# Mask, The Script success
# 322/1209---- start
# Indiana Jones IV Script success
# 323/1209---- start
# Gremlins Script success
# 324/1209---- start
# Producer, The Script success
# 325/1209---- start
# Kids Are All Right, The Script success
# 326/1209---- start
# Alien Nation Script success
# 327/1209---- start
# Neverending Story, The Script success
# 328/1209---- start
# Beauty and the Beast Script success
# 329/1209---- start
# Queen of the Damned Script success
# 330/1209---- start
# Pet Sematary II Script success
# 331/1209---- start
# Power of One, The Script success
# 332/1209---- start
# Station West Script success
# 333/1209---- start
# Man on the Moon Script success
# 334/1209---- start
# Gang Related Script success
# 335/1209---- start
# Lone Star Script success
# 336/1209---- start
# Priest Script success
# 337/1209---- start
# Princess Bride, The Script success
# 338/1209---- start
# Alien vs. Predator Script success
# 339/1209---- start
# Tin Cup Script success
# 340/1209---- start
# Horrible Bosses Script success
# 341/1209---- start
# American Beauty Script success
# 342/1209---- start
# Tamara Drewe Script success
# 343/1209---- start
# Mini's First Time Script success
# 344/1209---- start
# Spartan Script success
# 345/1209---- start
# Lost in Translation Script success
# 346/1209---- start
# French Connection, The Script success
# 347/1209---- start
# Philadelphia Script success
# 348/1209---- start
# Theory of Everything, The Script success
# 349/1209---- start
# Surrogates Script success
# 350/1209---- start
# Scream Script success
# 351/1209---- start
# Dry White Season, A Script success
# 352/1209---- start
# Hellboy Script success
# 353/1209---- start
# Prometheus Script success
# 354/1209---- start
# Wind Chill Script success
# 355/1209---- start
# Anastasia Script success
# 356/1209---- start
# Man Who Wasn't There, The Script success
# 357/1209---- start
# All About Eve Script success
# 358/1209---- start
# Fighter, The Script success
# 359/1209---- start
# Under Fire Script success
# 360/1209---- start
# Thor Script success
# 361/1209---- start
# Horse Whisperer, The Script success
# 362/1209---- start
# Night Time (The Poltergeist Treatment) Script success
# 363/1209---- start
# Grudge, The Script success
# 364/1209---- start
# Chinatown Script success
# 365/1209---- start
# Girl with the Dragon Tattoo, The Script success
# 366/1209---- start
# How to Train Your Dragon Script success
# 367/1209---- start
# Taking of Pelham One Two Three, The Script success
# 368/1209---- start
# Anonymous Script success
# 369/1209---- start
# Citizen Kane Script success
# 370/1209---- start
# You've Got Mail Script success
# 371/1209---- start
# Les Tontons Flingueurs Script success
# 372/1209---- start
# Sting, The Script success
# 373/1209---- start
# Adaptation Script success
# 374/1209---- start
# Frankenweenie Script success
# 375/1209---- start
# Sleepy Hollow Script success
# 376/1209---- start
# Above the Law Script success
# 377/1209---- start
# Funny People Script success
# 378/1209---- start
# Wild Things Script success
# 379/1209---- start
# Men Who Stare at Goats, The Script success
# 380/1209---- start
# Observe and Report Script success
# 381/1209---- start
# Breakfast Club, The Script success
# 382/1209---- start
# Debt, The Script success
# 383/1209---- start
# Man Who Knew Too Much, The Script success
# 384/1209---- start
# Boyhood Script success
# 385/1209---- start
# When a Stranger Calls Script success
# 386/1209---- start
# Mulan Script success
# 387/1209---- start
# Wall-E Script success
# 388/1209---- start
# Batman 2 Script success
# 389/1209---- start
# Sneakers Script success
# 390/1209---- start
# Escape From New York Script success
# 391/1209---- start
# Perfect World, A Script success
# 392/1209---- start
# Arsenic and Old Lace Script success
# 393/1209---- start
# 12 Script success
# 394/1209---- start
# Room Script success
# 395/1209---- start
# Starship Troopers Script success
# 396/1209---- start
# Life As A House Script success
# 397/1209---- start
# Lethal Weapon Script success
# 398/1209---- start
# Independence Day Script success
# 399/1209---- start
# Panic Room Script success
# 400/1209---- start
# Supergirl Script success
# 401/1209---- start
# O Brother Where Art Thou? Script success
# 402/1209---- start
# Rachel Getting Married Script success
# 403/1209---- start
# Best Exotic Marigold Hotel, The Script success
# 404/1209---- start
# Happy Birthday, Wanda June Script success
# 405/1209---- start
# Marty Script success
# 406/1209---- start
# Chaos Script success
# 407/1209---- start
# Little Men Script success
# 408/1209---- start
# Wild Things: Diamonds in the Rough Script success
# 409/1209---- start
# Foxcatcher Script success
# 410/1209---- start
# Mission to Mars Script success
# 411/1209---- start
# Rushmore Script success
# 412/1209---- start
# Burning Annie Script success
# 413/1209---- start
# Black Swan Script success
# 414/1209---- start
# Manhunter Script success
# 415/1209---- start
# Get Out Script success
# 416/1209---- start
# Wall Street Script success
# 417/1209---- start
# Buffy the Vampire Slayer Script success
# 418/1209---- start
# Cars 2 Script success
# 419/1209---- start
# Moonrise Kingdom Script success
# 420/1209---- start
# From Here to Eternity Script success
# 421/1209---- start
# Last Chance Harvey Script success
# 422/1209---- start
# Bad Teacher Script success
# 423/1209---- start
# Wizard of Oz, The Script success
# 424/1209---- start
# They Script success
# 425/1209---- start
# Reader, The Script success
# 426/1209---- start
# Enough Script success
# 427/1209---- start
# Freaked Script success
# 428/1209---- start
# Looper Script success
# 429/1209---- start
# Collateral Script success
# 430/1209---- start
# Marley & Me Script success
# 431/1209---- start
# Mulholland Drive Script success
# 432/1209---- start
# Custody Script success
# 433/1209---- start
# Bodies, Rest & Motion Script success
# 434/1209---- start
# Buried Script success
# 435/1209---- start
# Burlesque Script success
# 436/1209---- start
# Casino Script success
# 437/1209---- start
# It Happened One Night Script success
# 438/1209---- start
# Nurse Betty Script success
# 439/1209---- start
# Avengers, The (2012) Script success
# 440/1209---- start
# Walking Tall Script success
# 441/1209---- start
# Frequency Script success
# 442/1209---- start
# Harry Potter and the Chamber of Secrets Script success
# 443/1209---- start
# Lock, Stock and Two Smoking Barrels Script success
# 444/1209---- start
# Crouching Tiger, Hidden Dragon Script success
# 445/1209---- start
# Harry Potter and the Prisoner of Azkaban Script success
# 446/1209---- start
# Majestic, The (The Bijou) Script success
# 447/1209---- start
# Up in the Air Script success
# 448/1209---- start
# Resident Evil Script success
# 449/1209---- start
# Jane Eyre Script success
# 450/1209---- start
# We Own the Night Script success
# 451/1209---- start
# Adventures of Buckaroo Banzai Across the Eighth Dimension, The Script success
# 452/1209---- start
# Pianist, The Script success
# 453/1209---- start
# My Girl Script success
# 454/1209---- start
# Antitrust Script success
# 455/1209---- start
# Usual Suspects, The Script success
# 456/1209---- start
# Arctic Blue Script success
# 457/1209---- start
# Limey, The Script success
# 458/1209---- start
# Malibu's Most Wanted Script success
# 459/1209---- start
# Vertigo Script success
# 460/1209---- start
# Troy Script success
# 461/1209---- start
# Avventura, L' (The Adventure) Script success
# 462/1209---- start
# Orgy of the Dead Script success
# 463/1209---- start
# Fair Game Script success
# 464/1209---- start
# Wild Bunch, The Script success
# 465/1209---- start
# Ocean's Eleven Script success
# 466/1209---- start
# Machine Gun Preacher Script success
# 467/1209---- start
# The Rage: Carrie 2 Script success
# 468/1209---- start
# Bad Dreams Script success
# 469/1209---- start
# Crazylove Script success
# 470/1209---- start
# American Outlaws Script success
# 471/1209---- start
# Ice Storm, The Script success
# 472/1209---- start
# Blue Velvet Script success
# 473/1209---- start
# Taxi Driver Script success
# 474/1209---- start
# Ordinary People Script success
# 475/1209---- start
# State and Main Script success
# 476/1209---- start
# TRON: Legacy Script success
# 477/1209---- start
# Piano, The Script success
# 478/1209---- start
# Robin Hood: Prince of Thieves Script success
# 479/1209---- start
# Island, The Script success
# 480/1209---- start
# Argo Script success
# 481/1209---- start
# Celeste & Jesse Forever Script success
# 482/1209---- start
# Harry Potter and the Sorcerer's Stone Script success
# 483/1209---- start
# Courage Under Fire Script success
# 484/1209---- start
# Knocked Up Script success
# 485/1209---- start
# Raging Bull Script success
# 486/1209---- start
# King's Speech, The Script success
# 487/1209---- start
# Birdman Script success
# 488/1209---- start
# Oblivion Script success
# 489/1209---- start
# Sling Blade Script success
# 490/1209---- start
# Day of the Dead Script success
# 491/1209---- start
# Syriana Script success
# 492/1209---- start
# Four Feathers Script success
# 493/1209---- start
# Jade Script success
# 494/1209---- start
# At First Sight Script success
# 495/1209---- start
# Roughshod Script success
# 496/1209---- start
# Executive Decision Script success
# 497/1209---- start
# Belle Script success
# 498/1209---- start
# Good Girl, The Script success
# 499/1209---- start
# 44 Inch Chest Script success
# 500/1209---- start
# Case 39 Script success
# 501/1209---- start
# Sweet Hereafter, The Script success
# 502/1209---- start
# Innerspace Script success
# 503/1209---- start
# Blind Side, The Script success
# 504/1209---- start
# ParaNorman Script success
# 505/1209---- start
# Village, The Script success
# 506/1209---- start
# Sicario Script success
# 507/1209---- start
# His Girl Friday Script success
# 508/1209---- start
# Basquiat Script success
# 509/1209---- start
# What About Bob? Script success
# 510/1209---- start
# Day the Clown Cried, The Script success
# 511/1209---- start
# Benny & Joon Script success
# 512/1209---- start
# Extract Script success
# 513/1209---- start
# Blade: Trinity Script success
# 514/1209---- start
# Insidious Script success
# 515/1209---- start
# Warrior Script success
# 516/1209---- start
# Double Indemnity Script success
# 517/1209---- start
# Wonder Boys Script success
# 518/1209---- start
# Dave Barry's Complete Guide to Guys Script success
# 519/1209---- start
# Flash Gordon Script success
# 520/1209---- start
# Big Lebowski, The Script success
# 521/1209---- start
# Little Mermaid, The Script success
# 522/1209---- start
# Erin Brockovich Script success
# 523/1209---- start
# Crash Script success
# 524/1209---- start
# Brazil Script success
# 525/1209---- start
# Bounty Hunter, The Script success
# 526/1209---- start
# Three Men and a Baby Script success
# 527/1209---- start
# Heist Script success
# 528/1209---- start
# Source Code Script success
# 529/1209---- start
# Django Unchained Script success
# 530/1209---- start
# Batman and Robin Script success
# 531/1209---- start
# 12 and Holding Script success
# 532/1209---- start
# Ted Script success
# 533/1209---- start
# Sleepless in Seattle Script success
# 534/1209---- start
# TMNT Script success
# 535/1209---- start
# Master, The Script success
# 536/1209---- start
# Valkyrie Script success
# 537/1209---- start
# Coco Script success
# 538/1209---- start
# Margin Call Script success
# 539/1209---- start
# Woodsman, The Script success
# 540/1209---- start
# Natural Born Killers Script success
# 541/1209---- start
# Fantastic Mr Fox Script success
# 542/1209---- start
# Battle of Shaker Heights, The Script success
# 543/1209---- start
# Sugar and Spice Script success
# 544/1209---- start
# Witness Script success
# 545/1209---- start
# Detroit Rock City Script success
# 546/1209---- start
# Lost Horizon Script success
# 547/1209---- start
# Italian Job, The Script success
# 548/1209---- start
# Semi-Pro Script success
# 549/1209---- start
# Chronicle Script success
# 550/1209---- start
# Fault in Our Stars, The Script success
# 551/1209---- start
# Dune Script success
# 552/1209---- start
# Indiana Jones and the Temple of Doom Script success
# 553/1209---- start
# True Lies Script success
# 554/1209---- start
# Meet Joe Black Script success
# 555/1209---- start
# Aliens Script success
# 556/1209---- start
# Bad Day at Black Rock Script success
# 557/1209---- start
# Ghost Rider Script success
# 558/1209---- start
# Taking Sides Script success
# 559/1209---- start
# Blow Script success
# 560/1209---- start
# Machete Script success
# 561/1209---- start
# Beach, The Script success
# 562/1209---- start
# Air Force One Script success
# 563/1209---- start
# Batman Begins Script success
# 564/1209---- start
# Private Life of Sherlock Holmes, The Script success
# 565/1209---- start
# Silver Bullet Script success
# 566/1209---- start
# Broken Arrow Script success
# 567/1209---- start
# Watchmen Script success
# 568/1209---- start
# Jennifer's Body Script success
# 569/1209---- start
# I'll Do Anything Script success
# 570/1209---- start
# Confessions of a Dangerous Mind Script success
# 571/1209---- start
# Airplane 2: The Sequel Script success
# 572/1209---- start
# Gone Baby Gone Script success
# 573/1209---- start
# Logan Script success
# 574/1209---- start
# Beginners Script success
# 575/1209---- start
# Cruel Intentions Script success
# 576/1209---- start
# Doors, The Script success
# 577/1209---- start
# Scarface Script success
# 578/1209---- start
# Crime Spree Script success
# 579/1209---- start
# Kung Fu Panda Script success
# 580/1209---- start
# Basic Script success
# 581/1209---- start
# Fabulous Baker Boys, The Script success
# 582/1209---- start
# Single White Female Script success
# 583/1209---- start
# Star Trek: Generations Script success
# 584/1209---- start
# From Dusk Till Dawn Script success
# 585/1209---- start
# Intolerable Cruelty Script success
# 586/1209---- start
# Jurassic Park: The Lost World Script success
# 587/1209---- start
# Serenity Script success
# 588/1209---- start
# Henry Fool Script success
# 589/1209---- start
# Peeping Tom Script success
# 590/1209---- start
# Bean Script success
# 591/1209---- start
# Creation Script success
# 592/1209---- start
# Batman Forever Script success
# 593/1209---- start
# Silence of the Lambs Script success
# 594/1209---- start
# Snow Falling On Cedars Script success
# 595/1209---- start
# Cable Guy Script success
# 596/1209---- start
# Garden State Script success
# 597/1209---- start
# American Madness Script success
# 598/1209---- start
# Bachelor Party, The Script success
# 599/1209---- start
# Agnes of God Script success
# 600/1209---- start
# Ex Machina Script success
# 601/1209---- start
# Tristan and Isolde Script success
# 602/1209---- start
# Star Wars: Revenge of the Sith Script success
# 603/1209---- start
# X-Men Origins: Wolverine Script success
# 604/1209---- start
# Henry's Crime Script success
# 605/1209---- start
# Quantum Project Script success
# 606/1209---- start
# X-Men Script success
# 607/1209---- start
# E.T. Script success
# 608/1209---- start
# Gandhi Script success
# 609/1209---- start
# Get on Up Script success
# 610/1209---- start
# Swingers Script success
# 611/1209---- start
# Drag Me to Hell Script success
# 612/1209---- start
# Monster's Ball Script success
# 613/1209---- start
# Distinguished Gentleman, The Script success
# 614/1209---- start
# Nashville Script success
# 615/1209---- start
# American Graffiti Script success
# 616/1209---- start
# Star Wars: The Empire Strikes Back Script success
# 617/1209---- start
# Annie Hall Script success
# 618/1209---- start
# Face Off Script success
# 619/1209---- start
# Pulp Fiction Script success
# 620/1209---- start
# X-Files: Fight the Future, The Script success
# 621/1209---- start
# Wolf of Wall Street, The Script success
# 622/1209---- start
# Bourne Ultimatum, The Script success
# 623/1209---- start
# Abyss, The Script success
# 624/1209---- start
# Schindler's List Script success
# 625/1209---- start
# Evil Dead Script success
# 626/1209---- start
# Go Script success
# 627/1209---- start
# Mean Streets Script success
# 628/1209---- start
# 2001: A Space Odyssey Script success
# 629/1209---- start
# BlacKkKlansman Script success
# 630/1209---- start
# Star Trek: The Motion Picture Script success
# 631/1209---- start
# Box, The Script success
# 632/1209---- start
# Ringu Script success
# 633/1209---- start
# Back to the Future II & III Script success
# 634/1209---- start
# Little Nicky Script success
# 635/1209---- start
# Lord of Illusions Script success
# 636/1209---- start
# Hellbound: Hellraiser II Script success
# 637/1209---- start
# Indiana Jones and the Last Crusade Script success
# 638/1209---- start
# Stuntman, The Script success
# 639/1209---- start
# Jerry Maguire Script success
# 640/1209---- start
# Pearl Harbor Script success
# 641/1209---- start
# April Fool's Day Script success
# 642/1209---- start
# Beasts of No Nation Script success
# 643/1209---- start
# Pitch Black Script success
# 644/1209---- start
# Thelma & Louise Script success
# 645/1209---- start
# Addams Family, The Script success
# 646/1209---- start
# Full Metal Jacket Script success
# 647/1209---- start
# Break Script success
# 648/1209---- start
# Frozen (Disney) Script success
# 649/1209---- start
# Last Boy Scout, The Script success
# 650/1209---- start
# Very Bad Things Script success
# 651/1209---- start
# El Mariachi Script success
# 652/1209---- start
# Legally Blonde Script success
# 653/1209---- start
# Hospital, The Script success
# 654/1209---- start
# Tin Men Script success
# 655/1209---- start
# Scott Pilgrim vs the World Script success
# 656/1209---- start
# Authors Anonymous Script success
# 657/1209---- start
# Hot Tub Time Machine Script success
# 658/1209---- start
# Do The Right Thing Script success
# 659/1209---- start
# Hebrew Hammer, The Script success
# 660/1209---- start
# Awakenings Script success
# 661/1209---- start
# Lost Highway Script success
# 662/1209---- start
# Shifty Script success
# 663/1209---- start
# Logan's Run Script success
# 664/1209---- start
# Revenant, The Script success
# 665/1209---- start
# Hudson Hawk Script success
# 666/1209---- start
# Unbreakable Script success
# 667/1209---- start
# Being There Script success
# 668/1209---- start
# Major League Script success
# 669/1209---- start
# Meet John Doe Script success
# 670/1209---- start
# Eyes Wide Shut Script success
# 671/1209---- start
# Take Shelter Script success
# 672/1209---- start
# Alien: Resurrection Script success
# 673/1209---- start
# Wild At Heart Script success
# 674/1209---- start
# Smokin' Aces Script success
# 675/1209---- start
# Devil Wears Prada, The Script success
# 676/1209---- start
# Bruce Almighty Script success
# 677/1209---- start
# A Most Violent Year Script success
# 678/1209---- start
# Interstellar Script success
# 679/1209---- start
# St. Elmo's Fire Script success
# 680/1209---- start
# Jacob's Ladder Script success
# 681/1209---- start
# High Fidelity Script success
# 682/1209---- start
# Repo Man Script success
# 683/1209---- start
# Forrest Gump Script success
# 684/1209---- start
# Harry Potter and the Half-Blood Prince Script success
# 685/1209---- start
# Being John Malkovich Script success
# 686/1209---- start
# Basic Instinct Script success
# 687/1209---- start
# Flintstones, The Script success
# 688/1209---- start
# White Christmas Script success
# 689/1209---- start
# Sherlock Holmes Script success
# 690/1209---- start
# Commando Script success
# 691/1209---- start
# Death to Smoochy Script success
# 692/1209---- start
# Moonstruck Script success
# 693/1209---- start
# Shivers Script success
# 694/1209---- start
# Die Hard Script success
# 695/1209---- start
# Birds, The Script success
# 696/1209---- start
# American Splendor Script success
# 697/1209---- start
# Big Fish Script success
# 698/1209---- start
# Broken Embraces Script success
# 699/1209---- start
# Cowboys & Aliens Script success
# 700/1209---- start
# Easy A Script success
# 701/1209---- start
# Jurassic Park Script success
# 702/1209---- start
# 187 Script success
# 703/1209---- start
# Dumb and Dumber Script success
# 704/1209---- start
# Red Planet Script success
# 705/1209---- start
# Apartment, The Script success
# 706/1209---- start
# Arcade Script success
# 707/1209---- start
# After School Special Script success
# 708/1209---- start
# Chasing Amy Script success
# 709/1209---- start
# Dark Star Script success
# 710/1209---- start
# Into the Wild Script success
# 711/1209---- start
# Brothers Bloom, The Script success
# 712/1209---- start
# Apocalypse Now Script success
# 713/1209---- start
# Moneyball Script success
# 714/1209---- start
# Terminator Salvation Script success
# 715/1209---- start
# Gamer Script success
# 716/1209---- start
# Les Miserables Script success
# 717/1209---- start
# Matrix, The Script success
# 718/1209---- start
# Ali Script success
# 719/1209---- start
# Copycat Script success
# 720/1209---- start
# Zootopia Script success
# 721/1209---- start
# Batman Script success
# 722/1209---- start
# Despicable Me 2 Script success
# 723/1209---- start
# Secret Life of Walter Mitty, The Script success
# 724/1209---- start
# Rescuers Down Under, The Script success
# 725/1209---- start
# Joker Script success
# 726/1209---- start
# Simone Script success
# 727/1209---- start
# Ghost and the Darkness, The Script success
# 728/1209---- start
# Living in Oblivion Script success
# 729/1209---- start
# Jacket, The Script success
# 730/1209---- start
# Straight Outta Compton Script success
# 731/1209---- start
# My Best Friend's Wedding Script success
# 732/1209---- start
# Broadcast News Script success
# 733/1209---- start
# Hitchcock Script success
# 734/1209---- start
# Die Hard 2 Script success
# 735/1209---- start
# A Scanner Darkly Script success
# 736/1209---- start
# Scary Movie 2 Script success
# 737/1209---- start
# It's a Wonderful Life Script success
# 738/1209---- start
# Star Wars: The Phantom Menace Script success
# 739/1209---- start
# Next Script success
# 740/1209---- start
# Capote Script success
# 741/1209---- start
# How to Train Your Dragon 2 Script success
# 742/1209---- start
# Interview with the Vampire Script success
# 743/1209---- start
# Boondock Saints 2: All Saints Day Script success
# 744/1209---- start
# Event Horizon Script success
# 745/1209---- start
# Killing Zoe Script success
# 746/1209---- start
# Avengers, The Script success
# 747/1209---- start
# Program, The Script success
# 748/1209---- start
# Mission Impossible II Script success
# 749/1209---- start
# Phone Booth Script success
# 750/1209---- start
# Braveheart Script success
# 751/1209---- start
# LEGO Movie, The Script success
# 752/1209---- start
# Spider-Man Script success
# 753/1209---- start
# Never Been Kissed Script success
# 754/1209---- start
# Trainspotting Script success
# 755/1209---- start
# 17 Again Script success
# 756/1209---- start
# Assignment, The Script success
# 757/1209---- start
# Cherry Falls Script success
# 758/1209---- start
# Bourne Identity, The Script success
# 759/1209---- start
# Get Shorty Script success
# 760/1209---- start
# Something's Gotta Give Script success
# 761/1209---- start
# Honeydripper Script success
# 762/1209---- start
# Excalibur Script success
# 763/1209---- start
# Sex and the City Script success
# 764/1209---- start
# Battle: Los Angeles Script success
# 765/1209---- start
# I Am Number Four Script success
# 766/1209---- start
# Bodyguard Script success
# 767/1209---- start
# Fatal Instinct Script success
# 768/1209---- start
# Mumford Script success
# 769/1209---- start
# Other Boleyn Girl, The Script success
# 770/1209---- start
# What Lies Beneath Script success
# 771/1209---- start
# Cinema Paradiso Script success
# 772/1209---- start
# Papadopoulos & Sons Script success
# 773/1209---- start
# Someone To Watch Over Me Script success
# 774/1209---- start
# Blood Simple Script success
# 775/1209---- start
# Sessions, The Script success
# 776/1209---- start
# 15 Minutes Script success
# 777/1209---- start
# Blade Script success
# 778/1209---- start
# Croupier Script success
# 779/1209---- start
# Judge Dredd Script success
# 780/1209---- start
# Family Man, The Script success
# 781/1209---- start
# Matchstick Men Script success
# 782/1209---- start
# Nightmare on Elm Street: The Final Chapter Script success
# 783/1209---- start
# Human Nature Script success
# 784/1209---- start
# Last Station, The Script success
# 785/1209---- start
# Adjustment Bureau, The Script success
# 786/1209---- start
# Blade Runner Script success
# 787/1209---- start
# Drop Dead Gorgeous Script success
# 788/1209---- start
# Ronin Script success
# 789/1209---- start
# Blast from the Past, The Script success
# 790/1209---- start
# Last Flight, The Script success
# 791/1209---- start
# 12 Monkeys Script success
# 792/1209---- start
# Austin Powers - The Spy Who Shagged Me Script success
# 793/1209---- start
# Precious Script success
# 794/1209---- start
# Kramer vs Kramer Script success
# 795/1209---- start
# Gothika Script success
# 796/1209---- start
# Reindeer Games Script success
# 797/1209---- start
# Graduate, The Script success
# 798/1209---- start
# 30 Minutes or Less Script success
# 799/1209---- start
# 9 Script success
# 800/1209---- start
# A Few Good Men Script success
# 801/1209---- start
# Light Sleeper Script success
# 802/1209---- start
# Peggy Sue Got Married Script success
# 803/1209---- start
# War of the Worlds Script success
# 804/1209---- start
# Book of Eli, The Script success
# 805/1209---- start
# Sexual Life Script success
# 806/1209---- start
# Election Script success
# 807/1209---- start
# Klute Script success
# 808/1209---- start
# Star Trek II: The Wrath of Khan Script success
# 809/1209---- start
# Harold and Kumar Go to White Castle Script success
# 810/1209---- start
# Rambo: First Blood II: The Mission Script success
# 811/1209---- start
# Ticker Script success
# 812/1209---- start
# Walk to Remember, A Script success
# 813/1209---- start
# Affliction Script success
# 814/1209---- start
# Cobb Script success
# 815/1209---- start
# Thirteen Days Script success
# 816/1209---- start
# Juno Script success
# 817/1209---- start
# How to Lose Friends & Alienate People Script success
# 818/1209---- start
# Scream 3 Script success
# 819/1209---- start
# Sweet Smell of Success Script success
# 820/1209---- start
# Relic, The Script success
# 821/1209---- start
# Bad Country Script success
# 822/1209---- start
# Breaking Away Script success
# 823/1209---- start
# Cincinnati Kid, The Script success
# 824/1209---- start
# Terminator Script success
# 825/1209---- start
# A Serious Man Script success
# 826/1209---- start
# Jaws 2 Script success
# 827/1209---- start
# Hackers Script success
# 828/1209---- start
# Manchurian Candidate, The Script success
# 829/1209---- start
# Body of Evidence Script success
# 830/1209---- start
# Bling Ring, The Script success
# 831/1209---- start
# Talented Mr. Ripley, The Script success
# 832/1209---- start
# Mute Witness Script success
# 833/1209---- start
# Stir of Echoes Script success
# 834/1209---- start
# Friday the 13th Script success
# 835/1209---- start
# Barton Fink Script success
# 836/1209---- start
# American History X Script success
# 837/1209---- start
# Jaws Script success
# 838/1209---- start
# Crow: City of Angels, The Script success
# 839/1209---- start
# Alien Script success
# 840/1209---- start
# Bonfire of the Vanities Script success
# 841/1209---- start
# Space Milkshake Script success
# 842/1209---- start
# 50-50 Script success
# 843/1209---- start
# Seventh Seal, The Script success
# 844/1209---- start
# Shrek the Third Script success
# 845/1209---- start
# Gattaca Script success
# 846/1209---- start
# Spare Me Script success
# 847/1209---- start
# Erik the Viking Script success
# 848/1209---- start
# Tremors Script success
# 849/1209---- start
# Rush Script success
# 850/1209---- start
# Blade II Script success
# 851/1209---- start
# Orphan Script success
# 852/1209---- start
# Things My Father Never Taught Me, The Script success
# 853/1209---- start
# Constantine Script success
# 854/1209---- start
# Final Destination 2 Script success
# 855/1209---- start
# Eight Legged Freaks Script success
# 856/1209---- start
# Antz Script success
# 857/1209---- start
# Christ Complex Script success
# 858/1209---- start
# Brick Script success
# 859/1209---- start
# Spanglish Script success
# 860/1209---- start
# Highlander: Endgame Script success
# 861/1209---- start
# Gran Torino Script success
# 862/1209---- start
# When Harry Met Sally Script success
# 863/1209---- start
# Ninth Gate, The Script success
# 864/1209---- start
# Thunderheart Script success
# 865/1209---- start
# Great Gatsby, The Script success
# 866/1209---- start
# Hellboy 2: The Golden Army Script success
# 867/1209---- start
# Mighty Morphin Power Rangers: The Movie Script success
# 868/1209---- start
# Un Singe en Hiver Script success
# 869/1209---- start
# Se7en Script success
# 870/1209---- start
# Whiteout Script success
# 871/1209---- start
# Rambling Rose Script success
# 872/1209---- start
# 48 Hrs. Script success
# 873/1209---- start
# Amadeus Script success
# 874/1209---- start
# Margot at the Wedding Script success
# 875/1209---- start
# Heat Script success
# 876/1209---- start
# Boogie Nights Script success
# 877/1209---- start
# White Squall Script success
# 878/1209---- start
# Dances with Wolves Script success
# 879/1209---- start
# American Shaolin: King of Kickboxers II Script success
# 880/1209---- start
# Valentine's Day Script success
# 881/1209---- start
# All About Steve Script success
# 882/1209---- start
# Out of Sight Script success
# 883/1209---- start
# Contact Script success
# 884/1209---- start
# Pet Sematary Script success
# 885/1209---- start
# Big Blue, The Script success
# 886/1209---- start
# Deception Script success
# 887/1209---- start
# Man Trouble Script success
# 888/1209---- start
# Catwoman Script success
# 889/1209---- start
# Passengers Script success
# 890/1209---- start
# To Sleep with Anger Script success
# 891/1209---- start
# Tinker Tailor Soldier Spy Script success
# 892/1209---- start
# Fletch Script success
# 893/1209---- start
# Only God Forgives Script success
# 894/1209---- start
# Fifth Element, The Script success
# 895/1209---- start
# Rocky Horror Picture Show, The Script success
# 896/1209---- start
# Change-Up, The Script success
# 897/1209---- start
# Passion of Joan of Arc, The Script success
# 898/1209---- start
# Hudsucker Proxy, The Script success
# 899/1209---- start
# V for Vendetta Script success
# 900/1209---- start
# Coraline Script success
# 901/1209---- start
# Larry Crowne Script success
# 902/1209---- start
# Analyze This Script success
# 903/1209---- start
# Grapes of Wrath, The Script success
# 904/1209---- start
# Gravity Script success
# 905/1209---- start
# King of Comedy, The Script success
# 906/1209---- start
# Hunt for Red October, The Script success
# 907/1209---- start
# There's Something About Mary Script success
# 908/1209---- start
# Who's Your Daddy Script success
# 909/1209---- start
# True Romance Script success
# 910/1209---- start
# 500 Days of Summer Script success
# 911/1209---- start
# Fast Times at Ridgemont High Script success
# 912/1209---- start
# Mechanic, The Script success
# 913/1209---- start
# Mary Poppins Script success
# 914/1209---- start
# Lake Placid Script success
# 915/1209---- start
# Mirrors Script success
# 916/1209---- start
# Donnie Darko Script success
# 917/1209---- start
# Grosse Point Blank Script success
# 918/1209---- start
# Cirque du Freak: The Vampire's Assistant Script success
# 919/1209---- start
# Revolutionary Road Script success
# 920/1209---- start
# King Kong Script success
# 921/1209---- start
# Ghost Script success
# 922/1209---- start
# Alone in the Dark Script success
# 923/1209---- start
# American Sniper Script success
# 924/1209---- start
# American Milkshake Script success
# 925/1209---- start
# White Jazz Script success
# 926/1209---- start
# Frankenstein Script success
# 927/1209---- start
# Limitless Script success
# 928/1209---- start
# Mr Deeds Goes to Town Script success
# 929/1209---- start
# Warm Springs Script success
# 930/1209---- start
# Jay and Silent Bob Strike Back Script success
# 931/1209---- start
# Imaginarium of Doctor Parnassus, The Script success
# 932/1209---- start
# Grifters, The Script success
# 933/1209---- start
# Metro Script success
# 934/1209---- start
# Crow, The Script success
# 935/1209---- start
# Sunshine Cleaning Script success
# 936/1209---- start
# Long Kiss Goodnight, The Script success
# 937/1209---- start
# Manhattan Murder Mystery Script success
# 938/1209---- start
# Mimic Script success
# 939/1209---- start
# Bad Santa Script success
# 940/1209---- start
# Inception Script success
# 941/1209---- start
# 12 Years a Slave Script success
# 942/1209---- start
# Armageddon Script success
# 943/1209---- start
# Devil in a Blue Dress Script success
# 944/1209---- start
# Perfect Creature Script success
# 945/1209---- start
# Nick of Time Script success
# 946/1209---- start
# House of 1000 Corpses Script success
# 947/1209---- start
# Sideways Script success
# 948/1209---- start
# Halloween: The Curse of Michael Myers Script success
# 949/1209---- start
# Groundhog Day Script success
# 950/1209---- start
# L.A. Confidential Script success
# 951/1209---- start
# Disturbia Script success
# 952/1209---- start
# Dear White People Script success
# 953/1209---- start
# RocknRolla Script success
# 954/1209---- start
# Nine Script success
# 955/1209---- start
# Into the Woods Script success
# 956/1209---- start
# Le Diable par la Queue Script success
# 957/1209---- start
# Gangs of New York Script success
# 958/1209---- start
# Butterfly Effect, The Script success
# 959/1209---- start
# Miracle Worker, The Script success
# 960/1209---- start
# Alien 3 Script success
# 961/1209---- start
# Cider House Rules, The Script success
# 962/1209---- start
# Hitchhiker's Guide to the Galaxy, The Script success
# 963/1209---- start
# Midnight Cowboy Script success
# 964/1209---- start
# Her Script success
# 965/1209---- start
# Rebel Without A Cause Script success
# 966/1209---- start
# Shame Script success
# 967/1209---- start
# Help, The Script success
# 968/1209---- start
# Man in the Iron Mask Script success
# 969/1209---- start
# Being Human Script success
# 970/1209---- start
# Lincoln Lawyer, The Script success
# 971/1209---- start
# All the King's Men Script success
# 972/1209---- start
# Death at a Funeral Script success
# 973/1209---- start
# Godzilla Script success
# 974/1209---- start
# Cooler, The Script success
# 975/1209---- start
# 2012 Script success
# 976/1209---- start
# Big White, The Script success
# 977/1209---- start
# Dogma Script success
# 978/1209---- start
# Moon Script success
# 979/1209---- start
# Strangers on a Train Script success
# 980/1209---- start
# Highlander Script success
# 981/1209---- start
# Batman Returns Script success
# 982/1209---- start
# Mariachi, El Script success
# 983/1209---- start
# Transformers: The Movie Script success
# 984/1209---- start
# Hurt Locker, The Script success
# 985/1209---- start
# Super 8 Script success
# 986/1209---- start
# Way Back, The Script success
# 987/1209---- start
# Roommate, The Script success
# 988/1209---- start
# Amityville Asylum, The Script success
# 989/1209---- start
# Queen, The Script success
# 990/1209---- start
# Dark Knight, The Script success
# 991/1209---- start
# TRON Script success
# 992/1209---- start
# Invention of Lying, The Script success
# 993/1209---- start
# Napoleon Dynamite Script success
# 994/1209---- start
# Cedar Rapids Script success
# 995/1209---- start
# Nightmare on Elm Street, A Script success
# 996/1209---- start
# Crank Script success
# 997/1209---- start
# Heavenly Creatures Script success
# 998/1209---- start
# Cold Mountain Script success
# 999/1209---- start
# Three Kings Script success
# 1000/1209---- start
# Unforgiven Script success
# 1001/1209---- start
# Charlie's Angels Script success
# 1002/1209---- start
# Hanna Script success
# 1003/1209---- start
# Star Trek Script success
# 1004/1209---- start
# 28 Days Later Script success
# 1005/1209---- start
# No Country for Old Men Script success
# 1006/1209---- start
# Ghostbusters 2 Script success
# 1007/1209---- start
# Paul Script success
# 1008/1209---- start
# Candle to Water Script success
# 1009/1209---- start
# Gods and Monsters Script success
# 1010/1209---- start
# Gremlins 2 Script success
# 1011/1209---- start
# Ghost World Script success
# 1012/1209---- start
# Sixth Sense, The Script success
# 1013/1209---- start
# Ace Ventura: Pet Detective Script success
# 1014/1209---- start
# Top Gun Script success
# 1015/1209---- start
# Punch-Drunk Love Script success
# 1016/1209---- start
# Grabbers Script success
# 1017/1209---- start
# RKO 281 Script success
# 1018/1209---- start
# Deadpool Script success
# 1019/1209---- start
# Searchers, The Script success
# 1020/1209---- start
# Amour Script success
# 1021/1209---- start
# Ginger Snaps Script success
# 1022/1209---- start
# Clash of the Titans Script success
# 1023/1209---- start
# Megamind Script success
# 1024/1209---- start
# 8 Mile Script success
# 1025/1209---- start
# Bones Script success
# 1026/1209---- start
# Changeling Script success
# 1027/1209---- start
# Shallow Grave Script success
# 1028/1209---- start
# Hannah and Her Sisters Script success
# 1029/1209---- start
# Mummy, The Script success
# 1030/1209---- start
# Starman Script success
# 1031/1209---- start
# Star Wars: Return of the Jedi Script success
# 1032/1209---- start
# John Wick Script success
# 1033/1209---- start
# Twin Peaks Script success
# 1034/1209---- start
# Jennifer Eight Script success
# 1035/1209---- start
# Shipping News, The Script success
# 1036/1209---- start
# Return of the Apes Script success
# 1037/1209---- start
# Pi Script success
# 1038/1209---- start
# Indiana Jones and the Raiders of the Lost Ark Script success
# 1039/1209---- start
# Green Mile, The Script success
# 1040/1209---- start
# Leviathan Script success
# 1041/1209---- start
# Hollow Man Script success
# 1042/1209---- start
# South Park Script success
# 1043/1209---- start
# Fugitive, The Script success
# 1044/1209---- start
# Harry Potter and the Goblet of Fire Script success
# 1045/1209---- start
# Bridesmaids Script success
# 1046/1209---- start
# Youth in Revolt Script success
# 1047/1209---- start
# Casablanca Script success
# 1048/1209---- start
# Damned United, The Script success
# 1049/1209---- start
# Heathers Script success
# 1050/1209---- start
# Danish Girl, The Script success
# 1051/1209---- start
# Game 6 Script success
# 1052/1209---- start
# Notting Hill Script success
# 1053/1209---- start
# Shrek Script success
# 1054/1209---- start
# Hard to Kill Script success
# 1055/1209---- start
# Midnight Express Script success
# 1056/1209---- start
# Godfather Script success
# 1057/1209---- start
# This is 40 Script success
# 1058/1209---- start
# Blue Valentine Script success
# 1059/1209---- start
# Saving Mr. Banks Script success
# 1060/1209---- start
# Fear and Loathing in Las Vegas Script success
# 1061/1209---- start
# Saw Script success
# 1062/1209---- start
# Beloved Script success
# 1063/1209---- start
# Sex, Lies and Videotape Script success
# 1064/1209---- start
# La La Land Script success
# 1065/1209---- start
# Serial Mom Script success
# 1066/1209---- start
# Total Recall Script success
# 1067/1209---- start
# Rust and Bone Script success
# 1068/1209---- start
# Suspect Zero Script success
# 1069/1209---- start
# Pokemon: Mewtwo Returns Script success
# 1070/1209---- start
# Twilight: New Moon Script success
# 1071/1209---- start
# Five Easy Pieces Script success
# 1072/1209---- start
# Mrs. Brown Script success
# 1073/1209---- start
# Backdraft Script success
# 1074/1209---- start
# Ladykillers, The Script success
# 1075/1209---- start
# Jurassic Park III Script success
# 1076/1209---- start
# Obsessed Script success
# 1077/1209---- start
# Vanilla Sky Script success
# 1078/1209---- start
# Rock, The Script success
# 1079/1209---- start
# Losers, The Script success
# 1080/1209---- start
# Get Carter Script success
# 1081/1209---- start
# Tomorrow Never Dies Script success
# 1082/1209---- start
# Black Dahlia, The Script success
# 1083/1209---- start
# Glengarry Glen Gross Script success
# 1084/1209---- start
# Legend Script success
# 1085/1209---- start
# Two For The Money Script success
# 1086/1209---- start
# Black Rain Script success
# 1087/1209---- start
# Truman Show, The Script success
# 1088/1209---- start
# Ed TV Script success
# 1089/1209---- start
# New York Minute Script success
# 1090/1209---- start
# City of Joy Script success
# 1091/1209---- start
# It's Complicated Script success
# 1092/1209---- start
# 25th Hour Script success
# 1093/1209---- start
# Eastern Promises Script success
# 1094/1209---- start
# Collateral Damage Script success
# 1095/1209---- start
# Escape From L.A. Script success
# 1096/1209---- start
# Fury Script success
# 1097/1209---- start
# Nightbreed Script success
# 1098/1209---- start
# No Strings Attached Script success
# 1099/1209---- start
# Guardians of the Galaxy Vol 2 Script success
# 1100/1209---- start
# Ugly Truth, The Script success
# 1101/1209---- start
# Fracture Script success
# 1102/1209---- start
# Tourist, The Script success
# 1103/1209---- start
# Cast Away Script success
# 1104/1209---- start
# Duck Soup Script success
# 1105/1209---- start
# Three Musketeers, The Script success
# 1106/1209---- start
# Red Riding Hood Script success
# 1107/1209---- start
# Swordfish Script success
# 1108/1209---- start
# Heavy Metal Script success
# 1109/1209---- start
# Airplane Script success
# 1110/1209---- start
# Avatar Script success
# 1111/1209---- start
# Labyrinth Script success
# 1112/1209---- start
# Miller's Crossing Script success
# 1113/1209---- start
# One Flew Over the Cuckoo's Nest Script success
# 1114/1209---- start
# Frozen Script success
# 1115/1209---- start
# Four Rooms Script success
# 1116/1209---- start
# Cradle 2 the Grave Script success
# 1117/1209---- start
# Jackie Brown Script success
# 1118/1209---- start
# Men in Black 3 Script success
# 1119/1209---- start
# Platoon Script success
# 1120/1209---- start
# 10 Things I Hate About You Script success
# 1121/1209---- start
# Frances Script success
# 1122/1209---- start
# Invictus Script success
# 1123/1209---- start
# Replacements, The Script success
# 1124/1209---- start
# Mud Script success
# 1125/1209---- start
# Wild Hogs Script success
# 1126/1209---- start
# Sandlot Kids, The Script success
# 1127/1209---- start
# Almost Famous Script success
# 1128/1209---- start
# Romeo & Juliet Script success
# 1129/1209---- start
# 127 Hours Script success
# 1130/1209---- start
# Social Network, The Script success
# 1131/1209---- start
# Cube Script success
# 1132/1209---- start
# Point Break Script success
# 1133/1209---- start
# Absolute Power Script success
# 1134/1209---- start
# Confidence Script success
# 1135/1209---- start
# Crow Salvation, The Script success
# 1136/1209---- start
# Wag the Dog Script success
# 1137/1209---- start
# Platinum Blonde Script success
# 1138/1209---- start
# Birthday Girl Script success
# 1139/1209---- start
# U Turn Script success
# 1140/1209---- start
# Goodfellas Script success
# 1141/1209---- start
# You Can Count On Me Script success
# 1142/1209---- start
# A Prayer Before Dawn Script success
# 1143/1209---- start
# Chasing Sleep Script success
# 1144/1209---- start
# Charade Script success
# 1145/1209---- start
# Next Friday Script success
# 1146/1209---- start
# Big Sick, The Script success
# 1147/1209---- start
# Lethal Weapon 4 Script success
# 1148/1209---- start
# I am Sam Script success
# 1149/1209---- start
# Slither Script success
# 1150/1209---- start
# Star Trek: First Contact Script success
# 1151/1209---- start
# Willow Script success
# 1152/1209---- start
# Star Trek: Nemesis Script success
# 1153/1209---- start
# Rush Hour 2 Script success
# 1154/1209---- start
# American Hustle Script success
# 1155/1209---- start
# Enemy of the State Script success
# 1156/1209---- start
# Big Eyes Script success
# 1157/1209---- start
# Bourne Supremacy, The Script success
# 1158/1209---- start
# Hesher Script success
# 1159/1209---- start
# Hard Rain Script success
# 1160/1209---- start
# Mr Brooks Script success
# 1161/1209---- start
# Surfer King, The Script success
# 1162/1209---- start
# Elephant Man, The Script success
# 1163/1209---- start
# Ed Wood Script success
# 1164/1209---- start
# Entrapment Script success
# 1165/1209---- start
# White Ribbon, The Script success
# 1166/1209---- start
# Life Script success
# 1167/1209---- start
# Devil's Advocate Script success
# 1168/1209---- start
# American Psycho Script success
# 1169/1209---- start
# Liar Liar Script success
# 1170/1209---- start
# Jason X Script success
# 1171/1209---- start
# Hannibal Script success
# 1172/1209---- start
# Monkeybone Script success
# 1173/1209---- start
# 42 Script success
# 1174/1209---- start
# Inglourious Basterds Script success
# 1175/1209---- start
# Wild Wild West Script success
# 1176/1209---- start
# Pretty Woman Script success
# 1177/1209---- start
# Ruins, The Script success
# 1178/1209---- start
# I Still Know What You Did Last Summer Script success
# 1179/1209---- start
# Wonder Woman Script success
# 1180/1209---- start
# Austin Powers - International Man of Mystery Script success
# 1181/1209---- start
# True Grit Script success
# 1182/1209---- start
# Withnail and I Script success
# 1183/1209---- start
# Up Script success
# 1184/1209---- start
# Inventing the Abbotts Script success
# 1185/1209---- start
# While She Was Out Script success
# 1186/1209---- start
# I Love You Phillip Morris Script success
# 1187/1209---- start
# Runaway Bride Script success
# 1188/1209---- start
# Pirates of the Caribbean Script success
# 1189/1209---- start
# Star Wars: A New Hope Script success
# 1190/1209---- start
# Coriolanus Script success
# 1191/1209---- start
# Descendants, The Script success
# 1192/1209---- start
# Prestige, The Script success
# 1193/1209---- start
# Black Panther Script success
# 1194/1209---- start
# Martha Marcy May Marlene Script success
# 1195/1209---- start
# Fight Club Script success
# 1196/1209---- start
# Nines, The Script success
# 1197/1209---- start
# Hellraiser 3: Hell on Earth Script success
# 1198/1209---- start
# Mad Max 2: The Road Warrior Script success
# 1199/1209---- start
# Mighty Joe Young Script success
# 1200/1209---- start
# Lord of the Rings: The Two Towers Script success
# 1201/1209---- start
# Dark City Script success
# 1202/1209---- start
# World is not Enough, The Script success
# 1203/1209---- start
# My Week with Marilyn Script success
# 1204/1209---- start
# Bad Boys Script success
# 1205/1209---- start
# Kundun Script success
# 1206/1209---- start
# Hills Have Eyes, The Script success
# 1207/1209---- start
# Deer Hunter, The Script success
# 1208/1209---- start
# War for the Planet of the Apes Script success

# %%
import json

f = open(f"./data/movie_default.json", 'w')
json.dump(movie_infos, f)
f.close()

# %%
stop_words = "a's, able, im, uh, about, cod't, cont'd, above, according, accordingly, across, actually, after, afterwards, again, against, ain’t, all, allow, allows, almost, alone, along, already, also, although, always, am, among, amongst, an, and, another, any, anybody, anyhow, anyone, anything, anyway, anyways, anywhere, apart, appear, appreciate, appropriate, are, aren’t, around, as, aside, ask, asking, associated, at, available, away, awfully, be, became, because, become, becomes, becoming, been, before, beforehand, behind, being, believe, below, beside, besides, best, better, between, beyond, both, brief, but, by, c’mon, c’s, came, can, can’t, cannot, cant, cause, causes, certain, certainly, changes, clearly, co, com, come, comes, concerning, consequently, consider, considering, contain, containing, contains, corresponding, could, couldn’t, course, currently, definitely, described, despite, did, didn’t, different, do, does, doesn’t, doing, don’t, done, down, downwards, during, each, edu, eg, eight, either, else, elsewhere, enough, entirely, especially, et, etc, even, ever, every, everybody, everyone, everything, everywhere, ex, exactly, example, except, far, few, fifth, first, five, followed, following, follows, for, former, formerly, forth, four, from, further, furthermore, get, gets, getting, given, gives, go, goes, going, gone, got, gotten, greetings, had, hadn’t, happens, hardly, has, hasn’t, have, haven’t, having, he, he’s, hello, help, hence, her, here, here’s, hereafter, hereby, herein, hereupon, hers, herself, hi, him, himself, his, hither, hopefully, how, howbeit, however, i, i’d, i’ll, i’m, i’ve, ie, if, ignored, immediate, in, inasmuch, inc, indeed, indicate, indicated, indicates, inner, insofar, instead, into, inward, is, isn’t, it, it’d, it’ll, it’s, its, itself, just, keep, keeps, kept, know, knows, known, last, lately, later, latter, latterly, least, less, lest, let, let’s, like, liked, likely, little, look, looking, looks, ltd, mainly, many, may, maybe, me, mean, meanwhile, merely, might, more, moreover, most, mostly, much, must, my, myself, name, namely, nd, near, nearly, necessary, need, needs, neither, never, nevertheless, new, next, nine, no, nobody, non, none, noone, nor, normally, not, nothing, novel, now, nowhere, obviously, of, off, often, oh, ok, okay, old, on, once, one, ones, only, onto, or, other, others, otherwise, ought, our, ours, ourselves, out, outside, over, overall, own, particular, particularly, per, perhaps, placed, please, plus, possible, presumably, probably, provides, que, quite, qv, rather, rd, re, really, reasonably, regarding, regardless, regards, relatively, respectively, right, said, same, saw, say, saying, says, second, secondly, see, seeing, seem, seemed, seeming, seems, seen, self, selves, sensible, sent, serious, seriously, seven, several, shall, she, should, shouldn’t, since, six, so, some, somebody, somehow, someone, something, sometime, sometimes, somewhat, somewhere, soon, sorry, specified, specify, specifying, still, sub, such, sup, sure, t’s, take, taken, tell, tends, th, than, thank, thanks, thanx, that, that’s, thats, the, their, theirs, them, themselves, then, thence, there, there’s, thereafter, thereby, therefore, therein, theres, thereupon, these, they, they’d, they’ll, they’re, they’ve, think, third, this, thorough, thoroughly, those, though, three, through, throughout, thru, thus, to, together, too, took, toward, towards, tried, tries, truly, try, trying, twice, two, un, under, unfortunately, unless, unlikely, until, unto, up, upon, us, use, used, useful, uses, using, usually, value, various, very, via, viz, vs, want, wants, was, wasn’t, way, we, we’d, we’ll, we’re, we’ve, welcome, well, went, were, weren’t, what, what’s, whatever, when, whence, whenever, where, where’s, whereafter, whereas, whereby, wherein, whereupon, wherever, whether, which, while, whither, who, who’s, whoever, whole, whom, whose, why, will, willing, wish, with, within, without, won't, wonder, would, would, wouldn't, yes, yet, you, you'd, you'll, you're, you've, your, yours, yourself, yourselves, zero".replace('’',"'").split(', ')
end_words = '|'.join(['\,','\.','\?','\!','\-','\:','\;','\r','\n','\t','\(','\)','\{','\}',"\'s","\_","\&", "\#", "\@", "\#","\^","\*","\/","\[","\]"])

# %%
def process_texts(raw_script):
    end_replaced = re.sub(end_words, " ", raw_script.lower())
    # split
    script_chunks = end_replaced.split(' ')
    # remove stop_wrods
    filtered_script = filter(lambda x: len(x) > 1 and ((x in stop_words) is False), script_chunks)
    return filtered_script

# %%
def make_keyword_dict_and_count(keywords):
    keyword_list = ["{}".format(key.replace('"', "").replace("'","")) for key in list(set(keywords))]
#     print(f"tried with {len(keywords)} keywords")
    
    keyword_dict={key:0 for key in keyword_list}
    for raw_keyword in keywords:
        keyword = "{}".format(raw_keyword.replace('"', "").replace("'",""))
        keyword_dict.update({keyword:keyword_dict[keyword] + 1})
    return (keyword_list, keyword_dict)

# %%
def getMovieScripts(movie_name):
    headers = {
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Referer': 'https://imsdb.com/',
        'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    }
    response = requests.get(f"http://imsdb.com/scripts/{movie_name}.html", headers=headers, verify=False)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    raw_script = soup.find("td", class_='scrtext')
    try:
        raw_script = raw_script.find('pre')
        try:
            raw_script = raw_script.find('pre').text
        except:
            raw_script = raw_script.text
    except:
        val = soup.find("td", class_='scrtext')
        if val != None:
            raw_script = val.text
    if raw_script == None:
        raw_script = ""
    
    return movie_name, raw_script

# %%
def downloads(results, filename):
    with open(f"{filename}.json", "w") as json_file:
#         json.dump([val for val in results.values()], json_file)
        json.dump(results, json_file)
        json_file.close()
    
#     with open(f"{filename}_doc_infos.json", "w") as json_file:
#         json.dump([item for item in doc_data.items()], json_file)
#         json_file.close()

# %%
def storeScriptByGenres(genres=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Short', 'Thriller', 'War', 'Western']):
    results = {}
    doc_data = {}
    N_threads = 4
    for genre in genres:
        names = getNamesOfMovies(genre)
        count = 0
        name=""
        movie_data = []
        future_list = []
        with ThreadPoolExecutor(max_workers=N_threads) as e:
            for name in names:
                future = e.submit(getMovieScripts, name)
                future_list.append(future)
        
            (done, _) = wait(future_list)
            movie_data = [r.result() for r in done]
            try:
                downloads(movie_data, genre)
#                 for name, movie in movie_data:
#                     if name in results:
#                         doc_data[name].append(genre)
#                     else:
#                         results[name] = movie
#                         doc_data[name] = [genre]
#                     count+=1
                count += len(movie_data)
            except BaseException as e:
                print(str(e), f'while {genre} {name}')
            print(f"count {count}/{len(names)}")
#     return (results, doc_data)

# %%
storeScriptByGenres()
# Out:
# count 336/336
# count 203/203
# count 45/45
# count 394/394
# count 231/231
# count 652/652
# count 53/53
# count 130/130
# count 4/4
# count 158/158
# count 27/27
# count 123/123
# count 211/211
# count 180/180
# count 3/3

# %%
downloads(r,d)

# %%
import pandas as pd
import json
genres = ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Short', 'Thriller', 'War', 'Western']
counts = []

for genre in genres:
    f = open(f"./data/grouped_by_movie/preprocessed/{genre}.json")
    data = json.loads(f.read())
    f.close()
    counts.append(len(data))

pd.DataFrame([genres, counts])
# Out:
#        0          1          2       3      4      5       6        7   \
# 0  Action  Adventure  Animation  Comedy  Crime  Drama  Family  Fantasy
# 1     336        203         44     393    231    652      53      129
#
#           8       9        10       11       12      13     14        15   16  \
# 0  Film-Noir  Horror  Musical  Mystery  Romance  Sci-Fi  Short  Thriller  War
# 1          4     158       26      123      210     180      3       406   32
#
#         17
# 0  Western
# 1       17
